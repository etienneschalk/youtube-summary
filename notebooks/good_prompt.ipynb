# %% [markdown]
# Okay, the user is asking how to create a good prompt. Let me start by breaking down what a prompt is. It's essentially the instruction or question you give to an AI to get the desired response. To make a good one, clarity is key. The user needs to be specific about what they want. If they're too vague, the AI might not understand the context or the depth required.
#
# Next, I should consider the structure. Maybe outline the elements that make a prompt effective. Things like being specific, providing context, defining the role or persona for the AI, specifying the format, using examples, and iterating based on results. It's important to mention each of these points with examples to make it concrete.
#
# Wait, the user might be someone new to using AI, so examples would really help. For instance, comparing a vague prompt like "Explain photosynthesis" to a more specific one like "Explain photosynthesis to a 5th grader in simple terms, using analogies." Showing how specificity changes the output can make the advice more actionable.
#
# Also, the user might not know about the importance of context. Including context helps the AI tailor the response better. Like, if they need a summary for a research paper versus a blog post, the approach would differ. Mentioning that could help them get more precise results.
#
# Role definition is another aspect. Telling the AI to act as an expert in a certain field can improve the quality of the response. For example, "Act as a historian and explain the causes of World War II" versus just asking for an explanation.
#
# Format specification is crucial too. If they want a bullet list, a paragraph, or a table, stating that upfront saves time. Maybe include an example where asking for a step-by-step guide in bullet points leads to a more organized answer.
#
# Iteration is part of the process. Users might not realize that refining prompts based on initial responses can get them closer to what they need. Suggesting they tweak their prompts if the first answer isn't perfect would be helpful.
#
# I should also think about common mistakes. Overcomplicating the prompt, being too ambiguous, or assuming the AI knows the unspoken context. Pointing these out can help users avoid pitfalls.
#
# Lastly, maybe a quick checklist or summary at the end to recap the key points. That way, the user has a handy reference. Making sure the language is clear and not too technical, since the user might be a beginner. Alright, putting all these thoughts together into a structured answer with examples should cover the essentials of crafting a good prompt.
#
#
# Créer un **bon prompt** (consigne donnée à une IA) est essentiel pour obtenir des réponses précises et pertinentes. Voici une méthode structurée et des conseils pour y parvenir :
#
# ---
#
# ### **1. Soyez clair et spécifique**
# Évitez les formulations vagues. Plus votre demande est précise, plus l'IA peut cibler votre besoin.
# **Exemple :**
# ❌ *"Parle-moi de l'histoire de France."*
# ✅ *"Résume les causes de la Révolution française en 1789, en insistant sur les inégalités sociales et économiques."*
#
# ---
#
# ### **2. Définissez le contexte**
# Donnez des informations de base pour guider l'IA.
# **Exemple :**
# ❌ *"Écris un texte sur le changement climatique."*
# ✅ *"Écris un article engagé pour un public adolescent, expliquant l'impact de la fast fashion sur le réchauffement climatique."*
#
# ---
#
# ### **3. Précisez le format souhaité**
# Indiquez la structure attendue (liste, paragraphe, tableau, etc.).
# **Exemple :**
# ❌ *"Donne des conseils pour économiser l'eau."*
# ✅ *"Liste 10 astuces pratiques pour réduire sa consommation d'eau à la maison, sous forme de puces."*
#
# ---
#
# ### **4. Attribuez un rôle à l'IA**
# Pour des réponses expertes ou stylisées, spécifiez un "personnage" à incarner.
# **Exemple :**
# ✅ *"Agis comme un coach sportif professionnel et crée un programme d'entraînement de 4 semaines pour débutant."*
# ✅ *"Fais comme si tu étais un philosophe des Lumières et critique la société de consommation moderne."*
#
# ---
#
# ### **5. Utilisez des exemples**
# Montrez à l'IA le style ou le ton souhaité en fournissant un exemple.
# **Exemple :**
# ✅ *"Écris une métaphore poétique sur l'hiver, comme celle-ci : 'L'hiver est un peintre silencieux qui recouvre le monde de son pinceau glacé.'"*
#
# ---
#
# ### **6. Limitez les contraintes**
# Ajoutez des directives pour éviter les dérives ou les hors-sujets.
# **Exemple :**
# ✅ *"Rédige une recette de gâteau au chocolat sans produits laitiers, en moins de 300 mots."*
# ✅ *"Explique la théorie de la relativité sans utiliser de jargon technique."*
#
# ---
#
# ### **7. Itérez et affinez**
# Si la réponse ne convient pas, ajustez votre prompt en précisant vos attentes.
# **Exemple de suivi :**
# ✅ *"Peux-tu rendre ce texte plus formel et ajouter des statistiques récentes sur le sujet ?"*
#
# ---
#
# ### **Exemple de prompt optimisé**
# **Prompt initial :**
# *"Parle-moi de l'écologie."*
# **Prompt amélioré :**
# *"Agis comme une journaliste spécialisée en environnement. Écris un article percutant de 500 mots sur les avantages économiques de la transition écologique pour les PME françaises, avec des exemples concrets et des chiffres récents. Utilise un ton positif et engagé."*
#
# ---
#
# ### **Évitez ces erreurs**
# - **Trop de vagueur** : *"Fais quelque chose de créatif."* → Non-actionnable.
# - **Surcharge d’informations** : Évitez les consignes contradictoires ou trop longues.
# - **Présupposés** : Ne partez pas du principe que l’IA connaît votre contexte non explicitement mentionné.
#
# ---
#
# En résumé, un bon prompt est **précis, contextuel, structuré** et **itératif**. Plus vous guidez l'IA, plus elle devient un outil efficace pour vos besoins ! 🚀
#
# ---
# undefined: https://labs.perplexity.ai/?utm_source=copy_output
